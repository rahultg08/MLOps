# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_parquet("yellow_tripdata_2022-01.parquet")

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %% [markdown]
# ### Question1: Number of columns
# Ans: 19

# %%
df.shape
# Out:
# (2463931, 19)

# %%
df.shape[1]
# Out:
# 19

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %% [markdown]
# ### Question2. SD of duration
# Ans: 46.44

# %%
df['duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
df.loc[0, "duration"].total_seconds()
# Out:
# 1069.0

# %%
df.loc[0, "duration"].total_seconds()/60
# Out:
# 17.816666666666666

# %%
# converting duration from datetime format to float
df['duration'] = df['duration'].apply(lambda x: x.total_seconds()/60)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
df['duration'].dtypes
# Out:
# dtype('float64')

# %%
# standard deviation
df['duration'].std()
# Out:
# 46.44530513776499

# %% [markdown]
# ### Question3: Remaining fraction of data after removing the outliers
# Ans: 98.27

# %%
df['duration'].describe()
# Out:
# count    2.463931e+06
# mean     1.421220e+01
# std      4.644531e+01
# min     -3.442400e+03
# 25%      6.316667e+00
# 50%      1.018333e+01
# 75%      1.616667e+01
# max      8.513183e+03
# Name: duration, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2463931, step=1)

# %%
plt.scatter(df.index, df.duration)
plt.xlabel('index')
plt.ylabel('duration')
plt.title('Index vs Duration')
plt.show()

# %%
fig, ax = plt.subplots()
sns.distplot(df.duration, ax = ax)
ax.set_xlim(-150, 150)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.duration[(df['duration']<1)|(df['duration']>60)].size
# Out:
# 42491

# %%
df.shape
# Out:
# (2463931, 20)

# %%
(df.duration.size - df.duration[(df['duration']<1)|(df['duration']>60)].size)/df.duration.size
# Out:
# 0.9827547930522406

# %%
df = df[(df['duration']>=1) & (df['duration']<=60)]

# %%
df.shape
# Out:
# (2421440, 20)

# %%
df['duration'].hist(bins=50)
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.title('Histogram of Duration')
plt.show()

# %% [markdown]
# ### Question4: Number of columns after One-hot encoding
# Answer: 515

# %%
# do the one-hot encoding for the categorical variables
# convert df into dictionary and encode the df
# Convert the numeral values of IDs into string format, coz numerical values would not one-hot encoded and is left as is

# %%
categorical = ['PULocationID', 'DOLocationID']

# %%
df[categorical].dtypes
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %%
df[categorical].astype(str).dtypes
# Out:
# PULocationID    object
# DOLocationID    object
# dtype: object

# %%
df[categorical] = df[categorical].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                     object
# DOLocationID                     object
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# duration                        float64
# dtype: object

# %%
# Columnwise
df[categorical].iloc[:10, ].to_dict()
# Out:
# {'PULocationID': {0: '142',
#   1: '236',
#   2: '166',
#   3: '114',
#   4: '68',
#   5: '138',
#   6: '233',
#   7: '238',
#   8: '166',
#   9: '236'},
#  'DOLocationID': {0: '236',
#   1: '42',
#   2: '166',
#   3: '68',
#   4: '163',
#   5: '161',
#   6: '87',
#   7: '152',
#   8: '236',
#   9: '141'}}

# %%
# to convert into dictionary row wise
df[categorical].iloc[:10, ].to_dict(orient='records')
# Out:
# [{'PULocationID': '142', 'DOLocationID': '236'},
#  {'PULocationID': '236', 'DOLocationID': '42'},
#  {'PULocationID': '166', 'DOLocationID': '166'},
#  {'PULocationID': '114', 'DOLocationID': '68'},
#  {'PULocationID': '68', 'DOLocationID': '163'},
#  {'PULocationID': '138', 'DOLocationID': '161'},
#  {'PULocationID': '233', 'DOLocationID': '87'},
#  {'PULocationID': '238', 'DOLocationID': '152'},
#  {'PULocationID': '166', 'DOLocationID': '236'},
#  {'PULocationID': '236', 'DOLocationID': '141'}]

# %%
df_train = df[categorical].to_dict(orient='records')

# %%
# loading the DictVectorizer to perform OneHotEncoding
dv = DictVectorizer()

# %%
X_train = dv.fit_transform(df_train)

# %%
X_train
# Out:
# <2421440x515 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4842880 stored elements in Compressed Sparse Row format>

# %%
dv.feature_names_
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=105',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=109',
#  'DOLocationID=11',
#  'DOLocationID=111',
#  'DOLocationID=112',
#  'DOLocationID=113',
#  'DOLocationID=114',
#  'DOLocationID=115',
#  'DOLocationID=116',
#  'DOLocationID=117',
#  'DOLocationID=118',
#  'DOLocationID=119',
#  'DOLocationID=12',
#  'DOLocationID=120',
#  'DOLocationID=121',
#  'DOLocationID=122',
#  'DOLocationID=123',
#  'DOLocationID=124',
#  'DOLocationID=125',
#  'DOLocationID=126',
#  'DOLocationID=127',
#  'DOLocationID=128',
#  'DOLocationID=129',
#  'DOLocationID=13',
#  'DOLocationID=130',
#  'DOLocationID=131',
#  'DOLocationID=132',
#  'DOLocationID=133',
#  'DOLocationID=134',
#  'DOLocationID=135',
#  'DOLocationID=136',
#  'DOLocationID=137',
#  'DOLocationID=138',
#  'DOLocationID=139',
#  'DOLocationID=14',
# ...

# %%
# loading the target variable
target = 'duration'

# %%
y_train = df[target].values

# %%
X_train.shape[1]
# Out:
# 515

# %% [markdown]
# ### Question5: RMSE on trained model
# Answer: 6.986

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
sns.distplot(y_pred, label='Prediction')
sns.distplot(y_train, label='Actual')

plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Root Mean Squared Error
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 6.986190135968606

# %% [markdown]
# ### Question6. Evaluating the model
# Answer:

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_feb = read_dataframe('yellow_tripdata_2022-02.parquet')

# %%
df_train = read_dataframe('yellow_tripdata_2022-01.parquet')
df_val = read_dataframe('yellow_tripdata_2022-02.parquet')

# %%
dv = DictVectorizer()

train_dicts = df_train[categorical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

# %%
print('Question 6: RMSE on validation:', np.round(mean_squared_error(y_val, y_pred, squared=False),2))
# Out:
# Question 6: RMSE on validation: 7.79
